# %%
import spacy
from spacy import displacy
#from collections import Counter
import pandas as pd
from spacy.tokens import Doc
import re

# %%
nlp = spacy.load('es_core_news_md')

# %%
# filepath = '../texts/es.txt'
# text = open(filepath, encoding='utf-8').read()
# document = nlp(text)

# %%
text="Como un mago encerrado en su lampara, con la necesidad imperiosa de salir, con la alegría guardada: así se mostraron las miles de personas este sábado 26 de febrero cuando se reunieron en el centro histórico de Cuenca para ser parte, una vez más, del 'Carnaval Cuatro Ríos'.\nDesfile\nEn el reencuentro, porque para muchos \n fue una reunión postergada por la emergencia sanitaria, todas las edades primaron."

# %%
text=re.sub(r'([\w\.\,\"])\n([\w\.\,\"])',r'\1 \2',text)

# %%
text
# Out:
# "Como un mago encerrado en su lampara, con la necesidad imperiosa de salir, con la alegría guardada: así se mostraron las miles de personas este sábado 26 de febrero cuando se reunieron en el centro histórico de Cuenca para ser parte, una vez más, del 'Carnaval Cuatro Ríos'. Desfile En el reencuentro, porque para muchos \n fue una reunión postergada por la emergencia sanitaria, todas las edades primaron."

# %%
document = nlp(text)

# %%
document.__len__()
# Out:
# 79

# %%
document.text
# Out:
# "Como un mago encerrado en su lampara, con la necesidad imperiosa de salir, con la alegría guardada: así se mostraron las miles de personas este sábado 26 de febrero cuando se reunieron en el centro histórico de Cuenca para ser parte, una vez más, del 'Carnaval Cuatro Ríos'.\n En el reencuentro, porque para muchos fue una reunión postergada por la emergencia sanitaria, todas las edades primaron."

# %%
for token in document:
    print(token.pos_)
    print(token.morph)
    print(tagger(token))
# Out:
# SCONJ
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <module>
#       2 print(token.pos_)
#       3 print(token.morph)
# ----> 4 print(tagger(token))
#
# NameError: name 'tagger' is not defined

# %%
def tagger(token):
    dic_numero={"Sing":"singular","Plur":"plural"}
    dic_modo={"Imp":"imperativo","Ind":"indicativo","Sub":"subjuntivo"}
    dic_persona={"1":'primera',"2":"segunda","3":"tercera"}
    dic_tiempo={
        "Pres":"presente",
        "Past":"pretérito perfecto simple",
        "Imp":"pretérito imperfecto",
        "Fut":"futuro simple"                    
    }
    dic_genero={"Masc":"masculino","Fem":"femenino"}
    dic_numeral={"Card":"cardinal","Ord":"ordinal","Part":"partitivo"}
    if token.pos_ == "ADJ":
        clase="adjetivo"
        dic=token.morph.to_dict()
        try:
            numero=dic['Number']
            det1=dic_numero[numero]
        except:
            det1=""
        try:
            genero=dic['Gender']
            det2=dic_genero[genero]
        except:
            det2=""
        det3=""
        det4=""
    elif token.pos_ == "ADP":
        clase="preposición"
        det1=""
        det2=""
        det3=""
        det4=""
    elif token.pos_ == "ADV":
        clase="adverbio"
        det1=""
        det2=""
        det3=""
        det4=""
    elif token.pos_ == "AUX":
        clase="verbo"
        dic=token.morph.to_dict()
        try:
            if dic['VerbForm']=="Inf":
                det2="infinitivo simple"
                det1=""
                det3=""
                det4=""
            elif dic['VerbForm']=="Part":
                det2="participio pasado"
                det1=""
                det3=""
                det4=""
            elif dic['VerbForm']=="Ger":
                det2="gerundio simple"
                det1=""
                det3=""
                det4=""
            else:
                try:
                    modo=dic['Mood']
                    det1=dic_modo[modo]
                except:
                    det1=""
                try:
                    tiempo=dic['Tense']
                    det2=dic_tiempo[tiempo]
                except:
                    det2=""
                try:
                    persona=dic['Person']
                    det3=dic_persona[persona]
                except:
                    det3=""
                try:
                    numero=dic['Number']
                    det4=dic_numero[numero]
                except:
                    det4=""
        except:
            det1=""
            det2=""
            det3=""
            det4=""
    elif token.pos_ == "CCONJ":
        clase="conjunción"
        try:
            det1="coordinante"
        except:
            det1="" 
        det2=""
        det3=""
        det4=""
    elif token.pos_ == "DET":
        dic=token.morph.to_dict()
        try:
            preclase=dic['PronType']
            if preclase=="Art":
                clase="artículo"
                try:
                    numero=dic['Number']
                    det1=dic_numero[numero]
                except:
                    det1=""
                try:
                    genero=dic['Gender']
                    det2=dic_genero[genero]
                except:
                    det2=""
            else:
                clase="demostrativo"
                try:
                    numero=dic['Number']
                    det1=dic_numero[numero]
                except:
                    det1=""
                try:
                    genero=dic['Gender']
                    det2=dic_genero[genero]
                except:
                    det2="" 
            det3=""
            det4=""
        except:
            clase="artículo"
            det1=""
            det2=""
            det3=""
            det4=""
    elif token.pos_ == "INTJ":
        clase="interjección"
        det1=""
        det2=""
        det3=""
        det4=""
    elif token.pos_ == "NOUN":
        clase="sustantivo"
        dic=token.morph.to_dict()
        try:
            numero=dic['Number']
            det1=dic_numero[numero]
        except:
            det1=""
        try:
            genero=dic['Gender']
            det2=dic_genero[genero]
        except:
            det2=""
        det3=""
        det4=""
    elif token.pos_ == "NUM":
        clase="numeral"
        dic=token.morph.to_dict()
        try:
            numero=dic['Number']
            det1=dic_numero[numero]
        except:
            det1=""
        try:
            genero=dic['Gender']
            det2=dic_genero[genero]
        except:
            det2=""
        try:
            numeral=dic['NumType']
            det3=dic_numeral[numeral]
        except:
            det3=""
        det4=""
    elif token.pos_ == "PART":
        clase="afijo"
        det1=""
        det2=""
        det3=""
        det4=""
    elif token.pos_ == "PRON":
        dic=token.morph.to_dict()
        if dic['PronType']=="Prs":
            clase="pronombre personal"
            try:
                numero=dic['Number']
                det1=dic_numero[numero]
            except:
                det1=""
            try:
                genero=dic['Gender']
                det2=dic_genero[genero]
            except:
                det2=""
            try:
                persona=dic['Person']
                det3=dic_persona[persona]
            except:
                det3=""
            try:
                dic_casos={"Acc":"acusativo","Dat":"dativo"}
                caso=dic['Case']
                det4=dic_casos[caso]
            except:
                det4=""
        elif dic['PronType']=="Int,Rel":
            clase="relativo"
            try:
                numero=dic['Number']
                det1=dic_numero[numero]
            except:
                det1=""
            try:
                det2=dic['Gender']
            except:
                det2=""
            det3=""
            det4=""
        elif dic['PronType']=="Rel":
            clase="relativo"
            try:
                numero=dic['Number']
                det1=dic_numero[numero]
            except:
                det1=""
            try:
                genero=dic['Gender']
                det2=dic_genero[genero]
            except:
                det2=""
            det3=""
            det4=""
        elif dic['PronType']=="Int":
            clase="interrogativo"
            try:
                numero=dic['Number']
                det1=dic_numero[numero]
            except:
                det1=""
            try:
                genero=dic['Gender']
                det2=dic_genero[genero]
            except:
                det2=""
        else:
            clase="desconocido"
            det1=""
            det2=""
        det3=""
        det4=""
    elif token.pos_ == "PROPN":
        clase="sustantivo"
        det1=""
        det2=""
        det3=""
        det4=""
    elif token.pos_ == "PUNCT":
        clase="puntuación"
        det1=""
        det2=""
        det3=""
        det4=""        
    elif token.pos_ == "SCONJ":
        clase="conjunción"
        try:
            det1="subordinante"
        except:
            det1="" 
        det2=""
        det3=""
        det4=""      
    elif token.pos_ == "SYM":
        clase="desconocido"
        det1=""
        det2=""
        det3=""
        det4=""  
    elif token.pos_ == "VERB":
        clase="verbo"
        dic=token.morph.to_dict()
        try:
            if dic['VerbForm']=="Inf":
                det2="infinitivo simple"
                det1=""
                det3=""
                det4=""
            elif dic['VerbForm']=="Part":
                det2="participio pasado"
                det1=""
                det3=""
                det4=""
            elif dic['VerbForm']=="Ger":
                det2="gerundio simple"
                det1=""
                det3=""
                det4=""
            else:
                try:
                    modo=dic['Mood']
                    det1=dic_modo[modo]
                except:
                    det1=""
                try:
                    tiempo=dic['Tense']
                    det2=dic_tiempo[tiempo]
                except:
                    det2=""
                try:
                    persona=dic['Person']
                    det3=dic_persona[persona]
                except:
                    det3=""
                try:
                    numero=dic['Number']
                    det4=dic_numero[numero]
                except:
                    det4=""
        except:
            det1=""
            det2=""
            det3=""
            det4=""
    elif token.pos_ == "X":
        clase="desconocido"
        det1=""
        det2=""
        det3=""
        det4=""
    elif token.pos_ == "SPACE":
        clase="desconocido"
        det1=""
        det2=""
        det3=""
        det4=""
    #print(token.morph)
    return(token,clase,det1,det2,det3,det4)
            #,det5)
        #print(token.lemma_, token.pos_, token.dep_,token.morph)

# %% [markdown]
# ADJ: adjective
# ADP: adposition
# ADV: adverb
# AUX: auxiliary
# CCONJ: coordinating conjunction
# DET: determiner
# INTJ: interjection
# NOUN: noun
# NUM: numeral
# PART: particle
# PRON: pronoun
# PROPN: proper noun
# PUNCT: punctuation
# SCONJ: subordinating conjunction
# SYM: symbol
# VERB: verb
# X: other

# %%
clases=pd.read_csv('det1.csv',delimiter=";")

# %%
dic_pos={
    "ADJ": "adjectivo",
    "ADP": "preposición",
    "ADV": "adverbio",
    "AUX": "verbo",
    "CCONJ": "conjunción",
    "DET": "artículo",
    "INTJ": "interjección",
    "NOUN": "sustantivo",
    "NUM": "numeral",
    "PART": "particula",
    "PRON": "pronombre",
    "PROPN": "sustantivo",
    "PUNCT": "punctuación",
    "SCONJ": "conjunción",
    "SYM": "puntuación",
    "VERB": "verbo",
    "X": "desconocido"
}

# %%
for i,token,nlt in zip(range(len(document)),document,nltk_doc):
    print(i,token,nlt)
# Out:
# 0 Como Como
# 1 un un
# 2 mago mago
# 3 encerrado encerrado
# 4 en en
# 5 su su
# 6 lampara lampara
# 7 , ,
# 8 con con
# 9 la la
# 10 necesidad necesidad
# 11 imperiosa imperiosa
# 12 de de
# 13 salir salir
# 14 , ,
# 15 con con
# 16 la la
# 17 alegría alegría
# 18 guardada guardada
# 19 : :
# 20 así así
# 21 se se
# 22 mostraron mostraron
# 23 las las
# 24 miles miles
# 25 de de
# 26 personas personas
# 27 este este
# 28 sábado sábado
# 29 26 26
# 30 de de
# 31 febrero febrero
# 32 cuando cuando
# 33 se se
# 34 reunieron reunieron
# 35 en en
# 36 el el
# 37 centro centro
# 38 histórico histórico
# 39 de de
# 40 Cuenca Cuenca
# 41 para para
# 42 ser ser
# 43 parte parte
# 44 , ,
# 45 una una
# 46 vez vez
# 47 más más
# 48 , ,
# 49 del del
# 50 ' '
# 51 Carnaval Carnaval
# 52 Cuatro Cuatro
# 53 Ríos Ríos
# 54 ' '.
# 55 . En
# 56 En el
# 57 el reencuentro
# 58 reencuentro ,
# 59 , porque
# 60 porque para
# 61 para muchos
# 62 muchos fue
# 63 fue una
# 64 una reunión
# 65 reunión postergada
# 66 postergada por
# 67 por la
# 68 la emergencia
# 69 emergencia sanitaria
# 70 sanitaria ,
# 71 , todas
# 72 todas las
# 73 las edades
# 74 edades primaron
# 75 primaron .

# %%
import nltk
from nltk.tokenize import word_tokenize, wordpunct_tokenize

# %%
nltk_doc=wordpunct_tokenize(text)

# %%
for i,token in enumerate(document):
    print(i,token)
# Out:
# 0 Como
# 1 un
# 2 mago
# 3 encerrado
# 4 en
# 5 su
# 6 lampara
# 7 ,
# 8 con
# 9 la
# 10 necesidad
# 11 imperiosa
# 12 de
# 13 salir
# 14 ,
# 15 con
# 16 la
# 17 alegría
# 18 guardada
# 19 :
# 20 así
# 21 se
# 22 mostraron
# 23 las
# 24 miles
# 25 de
# 26 personas
# 27 este
# 28 sábado
# 29 26
# 30 de
# 31 febrero
# 32 cuando
# 33 se
# 34 reunieron
# 35 en
# 36 el
# 37 centro
# 38 histórico
# 39 de
# 40 Cuenca
# 41 para
# 42 ser
# 43 parte
# 44 ,
# 45 una
# 46 vez
# 47 más
# 48 ,
# 49 del
# 50 '
# 51 Carnaval
# 52 Cuatro
# 53 Ríos
# 54 '
# 55 .
# 56 En
# 57 el
# 58 reencuentro
# 59 ,
# 60 porque
# 61 para
# 62 muchos
# 63 fue
# 64 una
# 65 reunión
# 66 postergada
# 67 por
# 68 la
# 69 emergencia
# 70 sanitaria
# 71 ,
# 72 todas
# 73 las
# 74 edades
# 75 primaron
# 76 .

# %%
document[1].text
# Out:
# 'un'
